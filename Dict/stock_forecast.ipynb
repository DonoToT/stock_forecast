# %% [markdown]
# <a href="https://colab.research.google.com/github/DonoToT/stock_forecast/blob/main/Dict/stock_forecast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd drive/MyDrive/stock_forecast
# Out:
# /content/drive/MyDrive/stock_forecast

# %%
# %run train.py
# Out:
# ------对后1天的结果预测模型训练开始------
# ------第1轮训练开始------
# 整体训练集上的Loss: 117.46457707881927
# 整体训练集上的正确率: 0.8500304818153381
# 整体测试集上的Loss: 20.464815616607666
# 整体测试集上的正确率: 0.21023766696453094
# ------第2轮训练开始------
# 训练次数: 100, Loss: 1.4931504726409912
# 整体训练集上的Loss: 117.55536723136902
# 整体训练集上的正确率: 0.8534850478172302
# 整体测试集上的Loss: 20.493284463882446
# 整体测试集上的正确率: 0.20292505621910095
# ------第3轮训练开始------
# 训练次数: 200, Loss: 1.5335174798965454
# 整体训练集上的Loss: 117.42168116569519
# 整体训练集上的正确率: 0.8504369258880615
# 整体测试集上的Loss: 20.531133890151978
# 整体测试集上的正确率: 0.20109689235687256
# ------第4轮训练开始------
# 训练次数: 300, Loss: 1.4928793907165527
# 整体训练集上的Loss: 117.29099607467651
# 整体训练集上的正确率: 0.8516561388969421
# 整体测试集上的Loss: 20.537590265274048
# 整体测试集上的正确率: 0.20658135414123535
# ------第5轮训练开始------
# 整体训练集上的Loss: 117.21251618862152
# 整体训练集上的正确率: 0.8530786633491516
# 整体测试集上的Loss: 20.530336141586304
# 整体测试集上的正确率: 0.21023766696453094
# ------第6轮训练开始------
# 训练次数: 400, Loss: 1.474554181098938
# ...

# %%
# %run eval.py
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /content/drive/MyDrive/stock_forecast/eval.py in <module>
#      99
#     100
# --> 101 eval1()
#     102 # eval2()
#     103 # eval3()
#
# /content/drive/MyDrive/stock_forecast/eval.py in eval1()
#      36     model = torch.load("./models/stock_forecast1.pth", map_location=torch.device('cuda'))
#      37     model.eval()
# ---> 38     output = model(torch.tensor(test_data[0, :60]).to(torch.float32))
#      39     output = output.detach().numpy()
#      40     sum = output.sum()
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# ...
